# %%
# Call this installffmpeg script from your cluster init 
dbutils.fs.put("dbfs:/databricks/init/cpuml1/installffmpeg.sh","""
#!/usr/bin/env bash
apt-get update
sudo apt-get -y install ffmpeg
sudo apt-get -y install build-essential libssl1.0.0 libasound2 wget
sudo apt-get -y install protobuf-compiler libprotoc-dev
""", True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Wrote 191 bytes.
# Out[2]: True
# </div>

# %%
# %sql
CREATE TABLE Videos (id STRING, incoming_path STRING, completed_path STRING, incoming_audio STRING, completed_audio STRING)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
